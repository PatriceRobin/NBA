# %%
# %matplotlib inline
from main import *
from IPython.display import display
import seaborn as sns

# %%
player_name = "Stephen Curry"
shot_df = get_player_data(player_name, team_name="GSW", season_type="Regular Season", season ="2021-22")

with pd.option_context('display.max_columns', None):
    display(shot_df.head())
# Out:
#            GRID_TYPE     GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0  Shot Chart Detail  0022100002             37     201939  Stephen Curry
# 1  Shot Chart Detail  0022100002            176     201939  Stephen Curry
# 2  Shot Chart Detail  0022100002            352     201939  Stephen Curry
# 3  Shot Chart Detail  0022100002            510     201939  Stephen Curry
# 4  Shot Chart Detail  0022100002            642     201939  Stephen Curry
#
#       TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0  1610612744  Golden State Warriors       1                  9
# 1  1610612744  Golden State Warriors       1                  0
# 2  1610612744  Golden State Warriors       2                  1
# 3  1610612744  Golden State Warriors       3                  2
# 4  1610612744  Golden State Warriors       4                  5
#
#    SECONDS_REMAINING EVENT_TYPE                     ACTION_TYPE  \
# 0                 10  Made Shot                       Jump Shot
# 1                 27  Made Shot  Driving Finger Roll Layup Shot
# 2                 29  Made Shot                      Layup Shot
# 3                 23  Made Shot              Cutting Layup Shot
# 4                 34  Made Shot                       Jump Shot
#
#         SHOT_TYPE    SHOT_ZONE_BASIC        SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0  3PT Field Goal  Above the Break 3  Left Side Center(LC)          24+ ft.
# 1  2PT Field Goal    Restricted Area             Center(C)  Less Than 8 ft.
# 2  2PT Field Goal    Restricted Area             Center(C)  Less Than 8 ft.
# 3  2PT Field Goal    Restricted Area             Center(C)  Less Than 8 ft.
# 4  3PT Field Goal  Above the Break 3             Center(C)          24+ ft.
#
#    SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG GAME_DATE  \
# 0             25   -165    189                    1               1  20211019
# 1              2     -7     29                    1               1  20211019
# 2              1     -1     10                    1               1  20211019
# 3              1      7      8                    1               1  20211019
# 4             26     48    260                    1               1  20211019
#
#    HTM  VTM
# 0  LAL  GSW
# 1  LAL  GSW
# 2  LAL  GSW
# 3  LAL  GSW
# 4  LAL  GSW

# %%
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))
plt.scatter(shot_df.LOC_X, shot_df.LOC_Y)
plt.show()
#plot_court(player_name, team_name="GSW", season_type="Regular Season", season ="2021-22")
